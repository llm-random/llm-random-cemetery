# %%
dm = 1024
dff = 2816
blocks = 16
vocab = 50257
head = dm * vocab
ff = dm * dff * 3
att = dm ** 2 * 4
params = head + (ff + att) * blocks
f'{params:.2e}'
# Out:
# '2.57e+08'

# %%
seq = 1024
bs = 32
toks = 1000*bs*seq

# %%
flops = 6*toks*params

# %%
seconds = 10.42524 * 60

flops_per_sec = flops / seconds
mfu = flops_per_sec / (10 ** 12 * 1979 / 2)
mfu
# Out:
# 0.08163084039229401
