# %%
from transformers import  AutoTokenizer, GPT2TokenizerFast, BertTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained(
        "meta-llama/Llama-3.1-8B", add_bos_token=True, add_eos_token=True, legacy=False
    )

# %%
len(tokenizer), len(tokenizer) / 32, len(tokenizer) / 64
# Out:
# (128256, 4008.0, 2004.0)

# %%
gpttokenizer = GPT2TokenizerFast.from_pretrained("gpt2")

# %%
len(gpttokenizer), len(gpttokenizer) / 32, len(gpttokenizer) / 64
# Out:
# (50257, 1570.53125, 785.265625)

# %%
bt = BertTokenizer.from_pretrained("bert-base-uncased")

# %%
len(bt), len(bt) / 32, len(bt) / 64
# Out:
# (30522, 953.8125, 476.90625)

# %%
mb = AutoTokenizer.from_pretrained("answerdotai/ModernBERT-base")

# %%
mb
# Out:
# PreTrainedTokenizerFast(name_or_path='answerdotai/ModernBERT-base', vocab_size=50280, model_max_length=8192, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("|||IP_ADDRESS|||", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	1: AddedToken("<|padding|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	50254: AddedToken("                        ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50255: AddedToken("                       ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50256: AddedToken("                      ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# ...

# %%
len(mb), len(mb) / 32, len(mb) / 64
# Out:
# (50368, 1574.0, 787.0)

# %%
gpttokenizer
# Out:
# GPT2TokenizerFast(name_or_path='gpt2', vocab_size=50257, model_max_length=1024, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<|endoftext|>', 'eos_token': '<|endoftext|>', 'unk_token': '<|endoftext|>'}, clean_up_tokenization_spaces=False),  added_tokens_decoder={
# 	50256: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
# }

# %%
def print_tokenizer_len(tokenizer):
    return print(len(tokenizer), len(tokenizer) / 32, len(tokenizer) / 64)

print_tokenizer_len(gpttokenizer)
# Out:
# 50257 1570.53125 785.265625

# %%
gpttokenizer.add_special_tokens({"mask_token": "<|mask|>"})
# Out:
# 1

# %%
print_tokenizer_len(gpttokenizer)
# Out:
# 50258 1570.5625 785.28125

# %%
gpttokenizer.decode([50256, 50257])
# Out:
# '<|endoftext|><|mask|>'

# %%
tokenizer = GPT2TokenizerFast.from_pretrained("gpt2")
additional_special_tokens = [f"<|extra_token_{i}|>" for i in range(46)]
tokenizer.add_special_tokens({"mask_token": "<|mask|>", "additional_special_tokens": additional_special_tokens})
# Out:
# 47

# %%
len(tokenizer)
# Out:
# 50304

# %%
tokenizer.decode([i for i in range(50256, len(tokenizer))])
# Out:
# '<|endoftext|><|mask|><|extra_token_0|><|extra_token_1|><|extra_token_2|><|extra_token_3|><|extra_token_4|><|extra_token_5|><|extra_token_6|><|extra_token_7|><|extra_token_8|><|extra_token_9|><|extra_token_10|><|extra_token_11|><|extra_token_12|><|extra_token_13|><|extra_token_14|><|extra_token_15|><|extra_token_16|><|extra_token_17|><|extra_token_18|><|extra_token_19|><|extra_token_20|><|extra_token_21|><|extra_token_22|><|extra_token_23|><|extra_token_24|><|extra_token_25|><|extra_token_26|><|extra_token_27|><|extra_token_28|><|extra_token_29|><|extra_token_30|><|extra_token_31|><|extra_token_32|><|extra_token_33|><|extra_token_34|><|extra_token_35|><|extra_token_36|><|extra_token_37|><|extra_token_38|><|extra_token_39|><|extra_token_40|><|extra_token_41|><|extra_token_42|><|extra_token_43|><|extra_token_44|><|extra_token_45|>'

# %%
tokenizer.encode("<|mask|> Hello world! <|extra_token_0|> This is a test. <|extra_token_1|><|endoftext|><|endoftext|>")
# Out:
# [50257,
#  18435,
#  995,
#  0,
#  220,
#  50258,
#  770,
#  318,
#  257,
#  1332,
#  13,
#  220,
#  50259,
#  50256,
#  50256]

# %%
tokenizer.special_tokens_map
# Out:
# {'bos_token': '<|endoftext|>',
#  'eos_token': '<|endoftext|>',
#  'unk_token': '<|endoftext|>',
#  'mask_token': '<|mask|>',
#  'additional_special_tokens': ['<|extra_token_0|>',
#   '<|extra_token_1|>',
#   '<|extra_token_2|>',
#   '<|extra_token_3|>',
#   '<|extra_token_4|>',
#   '<|extra_token_5|>',
#   '<|extra_token_6|>',
#   '<|extra_token_7|>',
#   '<|extra_token_8|>',
#   '<|extra_token_9|>',
#   '<|extra_token_10|>',
#   '<|extra_token_11|>',
#   '<|extra_token_12|>',
#   '<|extra_token_13|>',
#   '<|extra_token_14|>',
#   '<|extra_token_15|>',
#   '<|extra_token_16|>',
#   '<|extra_token_17|>',
#   '<|extra_token_18|>',
#   '<|extra_token_19|>',
#   '<|extra_token_20|>',
#   '<|extra_token_21|>',
#   '<|extra_token_22|>',
#   '<|extra_token_23|>',
#   '<|extra_token_24|>',
#   '<|extra_token_25|>',
#   '<|extra_token_26|>',
#   '<|extra_token_27|>',
#   '<|extra_token_28|>',
#   '<|extra_token_29|>',
#   '<|extra_token_30|>',
#   '<|extra_token_31|>',
# ...

# %%
print_tokenizer_len(tokenizer)
# Out:
# 50304 1572.0 786.0

# %%
additional_special_tokens
# Out:
# ['<|extra_token_0|>',
#  '<|extra_token_1|>',
#  '<|extra_token_2|>',
#  '<|extra_token_3|>',
#  '<|extra_token_4|>',
#  '<|extra_token_5|>',
#  '<|extra_token_6|>',
#  '<|extra_token_7|>',
#  '<|extra_token_8|>',
#  '<|extra_token_9|>',
#  '<|extra_token_10|>',
#  '<|extra_token_11|>',
#  '<|extra_token_12|>',
#  '<|extra_token_13|>',
#  '<|extra_token_14|>',
#  '<|extra_token_15|>',
#  '<|extra_token_16|>',
#  '<|extra_token_17|>',
#  '<|extra_token_18|>',
#  '<|extra_token_19|>',
#  '<|extra_token_20|>',
#  '<|extra_token_21|>',
#  '<|extra_token_22|>',
#  '<|extra_token_23|>',
#  '<|extra_token_24|>',
#  '<|extra_token_25|>',
#  '<|extra_token_26|>',
#  '<|extra_token_27|>',
#  '<|extra_token_28|>',
#  '<|extra_token_29|>',
#  '<|extra_token_30|>',
#  '<|extra_token_31|>',
#  '<|extra_token_32|>',
#  '<|extra_token_33|>',
#  '<|extra_token_34|>',
#  '<|extra_token_35|>',
#  '<|extra_token_36|>',
#  '<|extra_token_37|>',
#  '<|extra_token_38|>',
#  '<|extra_token_39|>',
# ...

# %%
tokenizer
# Out:
# GPT2TokenizerFast(name_or_path='gpt2', vocab_size=50257, model_max_length=1024, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<|endoftext|>', 'eos_token': '<|endoftext|>', 'unk_token': '<|endoftext|>', 'mask_token': '<|mask|>', 'additional_special_tokens': ['<|extra_token_0|>', '<|extra_token_1|>', '<|extra_token_2|>', '<|extra_token_3|>', '<|extra_token_4|>', '<|extra_token_5|>', '<|extra_token_6|>', '<|extra_token_7|>', '<|extra_token_8|>', '<|extra_token_9|>', '<|extra_token_10|>', '<|extra_token_11|>', '<|extra_token_12|>', '<|extra_token_13|>', '<|extra_token_14|>', '<|extra_token_15|>', '<|extra_token_16|>', '<|extra_token_17|>', '<|extra_token_18|>', '<|extra_token_19|>', '<|extra_token_20|>', '<|extra_token_21|>', '<|extra_token_22|>', '<|extra_token_23|>', '<|extra_token_24|>', '<|extra_token_25|>', '<|extra_token_26|>', '<|extra_token_27|>', '<|extra_token_28|>', '<|extra_token_29|>', '<|extra_token_30|>', '<|extra_token_31|>', '
# ...

# %%
50304 - 50258
# Out:
# 46

# %%
tokenizer
# Out:
# PreTrainedTokenizerFast(name_or_path='meta-llama/Llama-3.1-8B', vocab_size=128000, model_max_length=131072, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<|begin_of_text|>', 'eos_token': '<|end_of_text|>'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	128000: AddedToken("<|begin_of_text|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	128001: AddedToken("<|end_of_text|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	128002: AddedToken("<|reserved_special_token_0|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	128003: AddedToken("<|reserved_special_token_1|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	128004: AddedToken("<|finetune_right_pad_id|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# ...
