# %%
from torchtune.datasets import alpaca_dataset, PackedDataset
from torchtune.models.llama3 import llama3_tokenizer

# Load in tokenizer
tokenizer = llama3_tokenizer(
    path="/Users/crewtool/.cache/huggingface/hub/models--meta-llama--Llama-3.2-1B",
    max_seq_len=8192,
)
dataset = alpaca_dataset(
    tokenizer=tokenizer,
    packed=True,
)
print(isinstance(dataset, PackedDataset))  # True
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 from torchtune.models.llama3 import llama3_tokenizer
#       4 # Load in tokenizer
# ----> 5 tokenizer = llama3_tokenizer(
#       6     path="/Users/crewtool/.cache/huggingface/hub/models--meta-llama--Llama-3.2-1B",
#       7     max_seq_len=8192,
#       8 )
#       9 dataset = alpaca_dataset(
#      10     tokenizer=tokenizer,
#      11     packed=True,
#      12 )
#      13 print(isinstance(dataset, PackedDataset))  # True
#
# File ~/nano/.venv/lib/python3.12/site-packages/torchtune/models/llama3/_model_builders.py:100, in llama3_tokenizer(path, special_tokens_path, max_seq_len, prompt_template)
#      92 special_tokens = (
#      93     parse_hf_tokenizer_json(special_tokens_path)
#      94     if special_tokens_path is not None
#      95     else None
#      96 )
#      97 template = (
#      98     _get_prompt_template(prompt_template) if prompt_template is not None else None
#      99 )
# --> 100 return Llama3Tokenizer(
#     101     path=path,
#     102     special_tokens=special_tokens,
#     103     max_seq_len=max_seq_len,
#     104     prompt_template=template,
#     105 )
#
# File ~/nano/.venv/lib/python3.12/site-packages/torchtune/models/llama3/_tokenizer.py:108, in Llama3Tokenizer.__init__(self, path, special_tokens, max_seq_len, prompt_template)
#     105 # During generation, stop when either eos_id, eot_id, or eom_id is encountered
#     106 self.stop_tokens = [self.eos_id, self.eot_id, self.eom_id]
# --> 108 self.tt_model = TikTokenBaseTokenizer(
#     109     path=path,
#     110     name="llama3_tiktoken",
#     111     pattern=CL100K_PATTERN,
#     112     bos_id=self.bos_id,
#     113     eos_id=self.eos_id,
#     114     special_tokens=self.special_tokens,
#     115 )
#     116 self.max_seq_len = max_seq_len
#     118 self.prompt_template = prompt_template
#
# File ~/nano/.venv/lib/python3.12/site-packages/torchtune/modules/transforms/tokenizers/_tiktoken.py:49, in TikTokenBaseTokenizer.__init__(self, path, name, pattern, bos_id, eos_id, special_tokens)
#      40 def __init__(
#      41     self,
#      42     path: str,
#    (...)     47     special_tokens: Dict[str, int],
#      48 ):
# ---> 49     mergeable_ranks = load_tiktoken_bpe(path)
#      50     self.tt_model = Encoding(
#      51         name=name,
#      52         pat_str=pattern,
#      53         mergeable_ranks=mergeable_ranks,
#      54         special_tokens=special_tokens,
#      55     )
#      56     # Vocab size without special tokens
#
# File ~/nano/.venv/lib/python3.12/site-packages/tiktoken/load.py:148, in load_tiktoken_bpe(tiktoken_bpe_file, expected_hash)
#     146 def load_tiktoken_bpe(tiktoken_bpe_file: str, expected_hash: str | None = None) -> dict[bytes, int]:
#     147     # NB: do not add caching to this function
# --> 148     contents = read_file_cached(tiktoken_bpe_file, expected_hash)
#     149     ret = {}
#     150     for line in contents.splitlines():
#
# File ~/nano/.venv/lib/python3.12/site-packages/tiktoken/load.py:63, in read_file_cached(blobpath, expected_hash)
#      60     except OSError:
#      61         pass
# ---> 63 contents = read_file(blobpath)
#      64 if expected_hash and not check_hash(contents, expected_hash):
#      65     raise ValueError(
#      66         f"Hash mismatch for data downloaded from {blobpath} (expected {expected_hash}). "
#      67         f"This may indicate a corrupted download. Please try again."
#      68     )
#
# File ~/nano/.venv/lib/python3.12/site-packages/tiktoken/load.py:16, in read_file(blobpath)
#      12     except ImportError as e:
#      13         raise ImportError(
#      14             "blobfile is not installed. Please install it by running `pip install blobfile`."
#      15         ) from e
# ---> 16     with blobfile.BlobFile(blobpath, "rb") as f:
#      17         return f.read()
#      19 # avoiding blobfile for public files helps avoid auth issues, like MFA prompts
#
# File ~/nano/.venv/lib/python3.12/site-packages/blobfile/_ops.py:393, in BlobFile(path, mode, streaming, buffer_size, cache_dir, file_size, version)
#     363 def BlobFile(
#     364     path: RemoteOrLocalPath,
#     365     mode: Literal["r", "rb", "w", "wb", "a", "ab"] = "r",
#    (...)    370     version: Optional[str] = None,
#     371 ):
#     372     """
#     373     Open a local or remote file for reading or writing
#     374
#    (...)    391         A file-like object
#     392     """
# --> 393     return default_context.BlobFile(
#     394         path=path,
#     395         mode=mode,
#     396         streaming=streaming,
#     397         buffer_size=buffer_size,
#     398         cache_dir=cache_dir,
#     399         file_size=file_size,
#     400         version=version,
#     401     )
#
# File ~/nano/.venv/lib/python3.12/site-packages/blobfile/_context.py:866, in Context.BlobFile(self, path, mode, streaming, buffer_size, cache_dir, file_size, version)
#     864 path = path_to_str(path)
#     865 if _guess_isdir(path):
# --> 866     raise IsADirectoryError(f"Is a directory: '{path}'")
#     868 if streaming is None:
#     869     streaming = mode in ("r", "rb")
#
# IsADirectoryError: Is a directory: '/Users/crewtool/.cache/huggingface/hub/models--meta-llama--Llama-3.2-1B'

# %%
import torch
from transformers import AutoTokenizer, GPT2LMHeadModel

tokenizer = AutoTokenizer.from_pretrained("openai-community/gpt2")
# model = GPT2LMHeadModel.from_pretrained("openai-community/gpt2")

inputs = tokenizer("Hello, my dog is cute", return_tensors="pt")
# outputs = model(**inputs, labels=inputs["input_ids"])
# loss = outputs.loss
# logits = outputs.logits

# %%
inputs
# Out:
# {'input_ids': tensor([[15496,    11,   616,  3290,   318, 13779]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
